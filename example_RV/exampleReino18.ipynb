# %% [markdown]
# # Mean velocity of the Hyades cluster
#
# The method was applied in Reino et al. (2018) consists of an iterative maximum-likelihood procedure
# to derive improved parallaxes for individual stars from their proper motions
# and radial velocities by kinematically modelling the cluster.
#
# Our method builds upon the maximum-likelihood method developed by Lindegren et al. (2000).
# Whereas Lindegren et al. (2000), being interested in deriving astrometric radial velocities (see also Dravins et al. 1999), formulated their model in terms of proper motions as main observables, we generalised this to include measured, spectroscopic radial velocities:
#
# 1. We added radial velocity, whenever available, as fourth observable, besides trigonometric parallax and proper motion;
#
# 2. We made a transition from the $\chi^2$ statistic used in Lindegren et al. (2000), and denoted $g$, to a $p$ value or $1 − CDF(g, DOF)$ as a goodness-of-fit statistic;
#
# 3. We used a mixed three- and four-dimensional likelihood function so that both stars with and without known radial velocity can be treated simultaneously.
#
# More details on the implementation of the method can be found in Reino et al. (2018), Section 5.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc


from covmatrix import *
from minim_rv import *
rc('text', usetex = True)
rc('font', family = 'serif', weight = 'normal', size =15)

# %%
def read_gaia(filename):
    data = np.genfromtxt('members_rv.bin', delimiter  = ',', names = True)
    N = len(data)
    ID = np.array(data['source_id'], dtype= int)
    w = np.where(ID == 0)
    ID[w] = data['HIP'][w]

    deg2rad = np.pi/180.
    coords = np.zeros((N, 2))
    coords[:, 0] = data['ra']*deg2rad
    coords[:, 1] = data['dec']*deg2rad

    obs  = np.zeros((N, 3))
    obs[:, 0] = data['parallax']
    obs[:, 1] = data['pmra']
    obs[:, 2] = data['pmdec']


    err = np.zeros((N, 3))
    err[:, 0] = data['parallax_error']
    err[:, 1] = data['pmra_error']
    err[:, 2] = data['pmdec_error']

    vrad = data['RV']
    err_vrad = data['e_RV']

    corr = np.zeros((N, 3))
    corr[:, 0] = data['parallax_pmra_corr']
    corr[:, 1] = data['parallax_pmdec_corr']
    corr[:, 2] = data['pmra_pmdec_corr']

    bminv = data['BV']
    vmag = data['Vmag']
    
    
    return ID, coords, obs, err, vrad, err_vrad, corr, N

# %%
filename = 'members_rv.bin'
ID, coords, obs_astro, err_astro, vrad, err_vrad, corr, N = read_gaia(filename)

# %% [markdown]
# When the radial velocity is not available, RV = nan.

# %% [markdown]
# Initial guesses for the cartesian equatorial velocity and the dispersion for the **Hyades** cluster (units are km/s):

# %%
vx, vy, vz = -6.32,   45.24,  5.3 
sigmav = 0.3                      
initial_guesses = np.concatenate((obs_astro[:, 0], np.array([vx, vy, vz, sigmav])))

# %% [markdown]
# First iteration. This is the same as in the *standard* procedure (without radial velocities).

# %%
grad = 'YES'
method = 'Newton-CG'

result, nit = optimizer(grad, method, initial_guesses, coords[:, 0], coords[: ,1],
                        obs_astro[:,0], obs_astro[:,1], obs_astro[:,2], 
                        vrad, err_astro, err_vrad, 
                        corr, N)
# Out:
# Optimization terminated successfully.
#          Current function value: 3868.103484
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 380
#          Hessian evaluations: 0

# %%
cl_fin = g_func(result, coords[:, 0], coords[:, 1], 
                obs_astro[:,0], obs_astro[:,1], obs_astro[:,2], 
                vrad, err_astro, err_vrad, corr, N)
cl_in =  g_func(initial_guesses, coords[:, 0], coords[:, 1], 
                obs_astro[:,0], obs_astro[:,1], obs_astro[:,2], 
                vrad, err_astro, err_vrad, corr, N)

# %%
H =  stella_Nmatrix_full(result, coords[:, 0], coords[:, 0], 
                         obs_astro[:,0], obs_astro[:,1], obs_astro[:,2], 
                         vrad, err_astro, err_vrad, corr, N)
invH =  np.linalg.inv(H)
err = np.zeros(N+4)
for i in range(N+4):
    err[i] = np.sqrt(invH[i,i])

print( 'vx: ',np.round(result[-4], 2), 'vy: ',np.round(result[-3],2),
      'vz: ', np.round(result[-2],2), 'sigma_v: ', np.round(result[-1], 2))

print( 'sigma_vx: ',np.round(err[-4], 2), 'sigma_vy: ',np.round(err[-3],2),
      'sigma_vz: ', np.round(err[-2],2), 'sigma_sigmav: ', np.round(err[-1], 2))

cl_fin_min = np.min(cl_fin)
print('Min CL value: ', np.round(cl_fin_min, 7))
# Out:
# vx:  -5.87 vy:  45.56 vz:  5.48 sigma_v:  0.96
# sigma_vx:  0.07 sigma_vy:  0.09 sigma_vz:  0.1 sigma_sigmav:  0.03
# Min CL value:  9.7e-06

# %%
cl_lim = 1-0.9973
while (cl_fin_min < cl_lim):
    N_survive = len(cl_fin[cl_fin > cl_fin_min])
    print('New N value: ', N_survive)

    ### Define new arrays with stars surviving the selection criterion
    coord_sel = np.zeros((N_survive, 2))
    astro_sel = np.zeros((N_survive, 3))
    vrad_sel = np.zeros(N_survive)
    err_sel, err_vrad_sel, corr_sel = np.zeros((N_survive, 3)), np.zeros(N_survive), np.zeros((N_survive, 3))
    ID_sel = np.zeros(N_survive)


    coord_sel[:, 0], coord_sel[:, 1] = coords[cl_fin > cl_fin_min, 0], coords[cl_fin > cl_fin_min, 1]
    astro_sel[:, 0], astro_sel[:, 1], astro_sel[:, 2] = obs_astro[cl_fin > cl_fin_min,0],\
                                                        obs_astro[cl_fin > cl_fin_min,1], \
                                                        obs_astro[cl_fin > cl_fin_min,2], 
    
    vrad_sel = vrad[cl_fin > cl_fin_min]
    
    err_sel[:, 0], err_sel[:, 1], err_sel[:, 2], err_vrad_sel = err_astro[cl_fin > cl_fin_min,0], \
                                                                err_astro[cl_fin > cl_fin_min,1],\
                                                                err_astro[cl_fin > cl_fin_min,2], \
                                                                err_vrad[cl_fin > cl_fin_min]
    corr_sel[:, 0], corr_sel[:, 1], corr_sel[:, 2] = corr[cl_fin > cl_fin_min,0], corr[cl_fin > cl_fin_min,1], \
                                                     corr[cl_fin > cl_fin_min,2] 
    
    ID_sel = ID[cl_fin > cl_fin_min]

    ID_reject = ID[(cl_fin <= cl_fin_min)][0]
    print('ID of excluded star: ', ID[(cl_fin <= cl_fin_min)])

    
    ### Minimize likelihood
    N = N_survive
    initial_guesses_sel =  np.concatenate((astro_sel[:, 0], np.array([vx, vy, vz, sigmav])))
    result, nit_sel = optimizer(grad, method, initial_guesses_sel, coord_sel[:, 0], coord_sel[:, 1], 
                                astro_sel[:, 0], astro_sel[:, 1], astro_sel[:, 2], vrad_sel, 
                                err_sel, err_vrad_sel, corr_sel, N)
    cl_fin = g_func(result, coord_sel[:, 0], coord_sel[:, 1], 
                                astro_sel[:, 0], astro_sel[:, 1], astro_sel[:, 2], vrad_sel, 
                                err_sel, err_vrad_sel, corr_sel, N)

    cl_fin_min = np.min(cl_fin)


    ### Compute errors on quantities.
    H =  stella_Nmatrix_full(result, coord_sel[:,0], 
                             coord_sel[:,0], astro_sel[:, 0], astro_sel[:, 1], astro_sel[:, 2],
                             vrad_sel, err_sel, err_vrad_sel, corr_sel, N)
    invH =  np.linalg.inv(H)

    err_param = np.zeros(N+4)
    for i in range(N+4):
        err_param[i] = np.sqrt(invH[i,i])

    ### Upload initial values
    coords = np.zeros((N, 2))
    obs_astro, err_astro, corr  = np.zeros((N, 3)), np.zeros((N, 3)), np.zeros((N, 3))
    coords[:, 0], coords[:,1] = coord_sel[: ,0], coord_sel[:, 1]
    obs_astro[:, 0], obs_astro[:, 1], obs_astro[:, 2] = astro_sel[:, 0], astro_sel[:, 1], astro_sel[:, 2]
    vrad = vrad_sel
    err_astro[:, 0], err_astro[:, 1], err_astro[:, 2], err_vrad = err_sel[:,0], err_sel[:,1], err_sel[:,2], err_vrad_sel
    corr[:, 0], corr[:, 1], corr[:, 2] = corr_sel[:, 0], corr_sel[:, 1], corr_sel[:, 2]
    ID = ID_sel


    U =  Ulike(result, coord_sel[:, 0], coord_sel[:, 1],
               astro_sel[:, 0],astro_sel[:, 1],astro_sel[:, 2], 
               vrad_sel, err_sel, err_vrad_sel, corr_sel, N)
    
    ### Print 
    print( 'Min CL value: ', cl_fin_min)
    print( 'Likelihood: ', U)
    print( 'v_x: ',result[-4], 'v_y: ',result[-3], 'v_z: ', result[-2], 'sigma_v: ', result[-1])
# Out:
# New N value:  250
# ID of excluded star:  [3309967055477808128]
# Optimization terminated successfully.
#          Current function value: 3828.221487
#          Iterations: 20
#          Function evaluations: 24
#          Gradient evaluations: 281
#          Hessian evaluations: 0
# Min CL value:  9.722496908e-06
# Likelihood:  3828.22148662
# v_x:  -5.8653942022 v_y:  45.5911702843 v_z:  5.48506762717 sigma_v:  0.942369924439
# New N value:  249
# ID of excluded star:  [38453460676522752]
# Optimization terminated successfully.
#          Current function value: 3797.021298
#          Iterations: 21
#          Function evaluations: 25
#          Gradient evaluations: 309
#          Hessian evaluations: 0
# Min CL value:  7.23598500551e-06
# Likelihood:  3797.02129757
# v_x:  -5.88276993433 v_y:  45.6072803501 v_z:  5.48075254748 sigma_v:  0.919209174418
# New N value:  248
# ID of excluded star:  [124145479935111424]
# Optimization terminated successfully.
#          Current function value: 3764.976093
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 345
#          Hessian evaluations: 0
# Min CL value:  7.28324052398e-06
# Likelihood:  3764.97609335
# v_x:  -5.89807060585 v_y:  45.625986349 v_z:  5.48486256365 sigma_v:  0.896683957872
# New N value:  247
# ID of excluded star:  [158941552620603776]
# Optimization terminated successfully.
#          Current function value: 3727.746513
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 288
#          Hessian evaluations: 0
# Min CL value:  8.03768544327e-06
# Likelihood:  3727.7465127
# v_x:  -5.8928830038 v_y:  45.6520932797 v_z:  5.48954563055 sigma_v:  0.890838372297
# New N value:  246
# ID of excluded star:  [2519811304873532416]
# Optimization terminated successfully.
#          Current function value: 3690.376307
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 326
#          Hessian evaluations: 0
# Min CL value:  1.36772337554e-05
# Likelihood:  3690.37630674
# v_x:  -5.90584600945 v_y:  45.6194027602 v_z:  5.47491561545 sigma_v:  0.878201376733
# New N value:  245
# ID of excluded star:  [3334853607820749312]
# Optimization terminated successfully.
#          Current function value: 3661.181674
#          Iterations: 22
#          Function evaluations: 23
#          Gradient evaluations: 368
#          Hessian evaluations: 0
# Min CL value:  1.78039127046e-05
# Likelihood:  3661.18167402
# v_x:  -5.92815763061 v_y:  45.6163372134 v_z:  5.46056115577 sigma_v:  0.854819630029
# New N value:  244
# ID of excluded star:  [3402663135604113920]
# Optimization terminated successfully.
#          Current function value: 3632.357603
#          Iterations: 21
#          Function evaluations: 22
#          Gradient evaluations: 294
#          Hessian evaluations: 0
# Min CL value:  1.58662292724e-05
# Likelihood:  3632.35760277
# v_x:  -5.94909842616 v_y:  45.6087080841 v_z:  5.46259626577 sigma_v:  0.834004025142
# New N value:  243
# ID of excluded star:  [12709]
# Optimization terminated successfully.
#          Current function value: 3590.195311
#          Iterations: 23
#          Function evaluations: 24
#          Gradient evaluations: 372
#          Hessian evaluations: 0
# Min CL value:  1.99126276007e-05
# Likelihood:  3590.19531098
# v_x:  -5.9626701773 v_y:  45.5844152461 v_z:  5.44488465925 sigma_v:  0.820546093406
# New N value:  242
# ID of excluded star:  [10608569223157760]
# Optimization terminated successfully.
#          Current function value: 3554.663470
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 308
#          Hessian evaluations: 0
# Min CL value:  7.12927939098e-05
# Likelihood:  3554.66347044
# v_x:  -5.95381405307 v_y:  45.5627337564 v_z:  5.45514462576 sigma_v:  0.796453751939
# New N value:  241
# ID of excluded star:  [3313845101709242368]
# Optimization terminated successfully.
#          Current function value: 3517.625373
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 359
#          Hessian evaluations: 0
# Min CL value:  9.26034156816e-05
# Likelihood:  3517.62537293
# v_x:  -5.96857718752 v_y:  45.5772672163 v_z:  5.45062880713 sigma_v:  0.779288008967
# New N value:  240
# ID of excluded star:  [21459]
# Optimization terminated successfully.
#          Current function value: 3484.833411
#          Iterations: 22
#          Function evaluations: 24
#          Gradient evaluations: 387
#          Hessian evaluations: 0
# Min CL value:  0.000110244332162
# Likelihood:  3484.83341133
# v_x:  -5.9598713166 v_y:  45.553973177 v_z:  5.44791433528 sigma_v:  0.766673897969
# New N value:  239
# ID of excluded star:  [3239532512402275328]
# Optimization terminated successfully.
#          Current function value: 3458.689513
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 382
#          Hessian evaluations: 0
# Min CL value:  0.000112495622539
# Likelihood:  3458.68951258
# v_x:  -5.95370305964 v_y:  45.5580418557 v_z:  5.46512602931 sigma_v:  0.747046087826
# New N value:  238
# ID of excluded star:  [10584895361388800]
# Optimization terminated successfully.
#          Current function value: 3427.110854
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 412
#          Hessian evaluations: 0
# Min CL value:  6.89921233319e-05
# Likelihood:  3427.11085416
# v_x:  -5.94666773482 v_y:  45.5429247632 v_z:  5.4766940009 sigma_v:  0.726996833999
# New N value:  237
# ID of excluded star:  [3226859610099438592]
# Optimization terminated successfully.
#          Current function value: 3401.178100
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 404
#          Hessian evaluations: 0
# Min CL value:  5.84620907696e-05
# Likelihood:  3401.17809971
# v_x:  -5.94138818517 v_y:  45.5535606403 v_z:  5.4946956812 sigma_v:  0.706253915497
# New N value:  236
# ID of excluded star:  [22221]
# Optimization terminated successfully.
#          Current function value: 3366.100280
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 394
#          Hessian evaluations: 0
# Min CL value:  6.48012949519e-05
# Likelihood:  3366.10028005
# v_x:  -5.95284773464 v_y:  45.5544753317 v_z:  5.50177385659 sigma_v:  0.691396915286
# New N value:  235
# ID of excluded star:  [151650072541569280]
# Optimization terminated successfully.
#          Current function value: 3329.818048
#          Iterations: 21
#          Function evaluations: 25
#          Gradient evaluations: 379
#          Hessian evaluations: 0
# Min CL value:  5.18187795564e-05
# Likelihood:  3329.81804818
# v_x:  -5.96090895968 v_y:  45.5813775942 v_z:  5.50083397545 sigma_v:  0.672585046308
# New N value:  234
# ID of excluded star:  [3340209775636513280]
# Optimization terminated successfully.
#          Current function value: 3303.428172
#          Iterations: 21
#          Function evaluations: 25
#          Gradient evaluations: 393
#          Hessian evaluations: 0
# Min CL value:  5.11600026408e-05
# Likelihood:  3303.42817234
# v_x:  -5.97701862882 v_y:  45.5760185966 v_z:  5.50071545049 sigma_v:  0.660693819634
# New N value:  233
# ID of excluded star:  [114842099735769856]
# Optimization terminated successfully.
#          Current function value: 3277.490692
#          Iterations: 15
#          Function evaluations: 18
#          Gradient evaluations: 168
#          Hessian evaluations: 0
# Min CL value:  8.53634565114e-05
# Likelihood:  3277.49069241
# v_x:  -5.97094132609 v_y:  45.5766671149 v_z:  5.49099025058 sigma_v:  0.645143658328
# New N value:  232
# ID of excluded star:  [3284709349242833920]
# Optimization terminated successfully.
#          Current function value: 3252.640996
#          Iterations: 15
#          Function evaluations: 19
#          Gradient evaluations: 167
#          Hessian evaluations: 0
# Min CL value:  9.82544191802e-05
# Likelihood:  3252.6409959
# v_x:  -5.9823529298 v_y:  45.579748472 v_z:  5.47797119131 sigma_v:  0.631289178219
# New N value:  231
# ID of excluded star:  [21683]
# Optimization terminated successfully.
#          Current function value: 3218.756890
#          Iterations: 23
#          Function evaluations: 27
#          Gradient evaluations: 415
#          Hessian evaluations: 0
# Min CL value:  6.31682200018e-05
# Likelihood:  3218.75688998
# v_x:  -5.99362722237 v_y:  45.5885018823 v_z:  5.47210196331 sigma_v:  0.613563494984
# New N value:  230
# ID of excluded star:  [82603594175480320]
# Optimization terminated successfully.
#          Current function value: 3193.140915
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 350
#          Hessian evaluations: 0
# Min CL value:  6.0299090438e-05
# Likelihood:  3193.14091468
# v_x:  -5.99450886386 v_y:  45.5876782752 v_z:  5.48421947282 sigma_v:  0.595656459309
# New N value:  229
# ID of excluded star:  [3306066434899058688]
# Optimization terminated successfully.
#          Current function value: 3167.296938
#          Iterations: 24
#          Function evaluations: 27
#          Gradient evaluations: 494
#          Hessian evaluations: 0
# Min CL value:  4.51725597652e-05
# Likelihood:  3167.29693821
# v_x:  -5.99857646158 v_y:  45.5920535672 v_z:  5.49607639305 sigma_v:  0.575953784582
# New N value:  228
# ID of excluded star:  [114317976286533888]
# Optimization terminated successfully.
#          Current function value: 3141.476651
#          Iterations: 14
#          Function evaluations: 19
#          Gradient evaluations: 196
#          Hessian evaluations: 0
# Min CL value:  6.39821947657e-05
# Likelihood:  3141.47665079
# v_x:  -6.00355521792 v_y:  45.586071516 v_z:  5.5025434063 sigma_v:  0.56477330681
# New N value:  227
# ID of excluded star:  [3283823383388618752]
# Optimization terminated successfully.
#          Current function value: 3112.191730
#          Iterations: 13
#          Function evaluations: 19
#          Gradient evaluations: 165
#          Hessian evaluations: 0
# Min CL value:  4.53951237081e-05
# Likelihood:  3112.19172964
# v_x:  -5.99214361256 v_y:  45.5776090129 v_z:  5.51362863979 sigma_v:  0.54494948863
# New N value:  226
# ID of excluded star:  [79881650062116352]
# Optimization terminated successfully.
#          Current function value: 3085.852597
#          Iterations: 13
#          Function evaluations: 19
#          Gradient evaluations: 165
#          Hessian evaluations: 0
# Min CL value:  4.85646975824e-05
# Likelihood:  3085.85259726
# v_x:  -5.99112653567 v_y:  45.5732072396 v_z:  5.52530710431 sigma_v:  0.525913162012
# New N value:  225
# ID of excluded star:  [3422091368627962880]
# Optimization terminated successfully.
#          Current function value: 3048.782845
#          Iterations: 21
#          Function evaluations: 25
#          Gradient evaluations: 391
#          Hessian evaluations: 0
# Min CL value:  5.83819922603e-05
# Likelihood:  3048.78284505
# v_x:  -5.99418643956 v_y:  45.5451488797 v_z:  5.51944229271 sigma_v:  0.529640954676
# New N value:  224
# ID of excluded star:  [26259120810103552]
# Optimization terminated successfully.
#          Current function value: 3024.140723
#          Iterations: 22
#          Function evaluations: 27
#          Gradient evaluations: 430
#          Hessian evaluations: 0
# Min CL value:  5.76445660618e-05
# Likelihood:  3024.14072345
# v_x:  -5.99236847979 v_y:  45.5510922898 v_z:  5.53211356527 sigma_v:  0.513573391333
# New N value:  223
# ID of excluded star:  [76117300205326976]
# Optimization terminated successfully.
#          Current function value: 2996.387231
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 438
#          Hessian evaluations: 0
# Min CL value:  4.96654511344e-05
# Likelihood:  2996.38723138
# v_x:  -5.99297487232 v_y:  45.5598086581 v_z:  5.52568282235 sigma_v:  0.505471506689
# New N value:  222
# ID of excluded star:  [18735]
# Optimization terminated successfully.
#          Current function value: 2964.888911
#          Iterations: 21
#          Function evaluations: 26
#          Gradient evaluations: 398
#          Hessian evaluations: 0
# Min CL value:  6.16439447696e-05
# Likelihood:  2964.88891086
# v_x:  -5.99058081705 v_y:  45.5894553882 v_z:  5.53141791718 sigma_v:  0.499698559539
# New N value:  221
# ID of excluded star:  [20713]
# Optimization terminated successfully.
#          Current function value: 2929.661552
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 458
#          Hessian evaluations: 0
# Min CL value:  5.27512074075e-05
# Likelihood:  2929.6615524
# v_x:  -5.98283675994 v_y:  45.5835041999 v_z:  5.54063300028 sigma_v:  0.48834025028
# New N value:  220
# ID of excluded star:  [21588]
# Optimization terminated successfully.
#          Current function value: 2893.583980
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 492
#          Hessian evaluations: 0
# Min CL value:  7.39711565933e-05
# Likelihood:  2893.5839803
# v_x:  -5.97823043007 v_y:  45.5899280003 v_z:  5.55111969926 sigma_v:  0.480294593732
# New N value:  219
# ID of excluded star:  [20719]
# Optimization terminated successfully.
#          Current function value: 2860.041881
#          Iterations: 22
#          Function evaluations: 27
#          Gradient evaluations: 438
#          Hessian evaluations: 0
# Min CL value:  3.10126108581e-05
# Likelihood:  2860.04188065
# v_x:  -5.97767066401 v_y:  45.5970467862 v_z:  5.54111658182 sigma_v:  0.462901093994
# New N value:  218
# ID of excluded star:  [20885]
# Optimization terminated successfully.
#          Current function value: 2827.409250
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 494
#          Hessian evaluations: 0
# Min CL value:  5.15920712075e-05
# Likelihood:  2827.4092495
# v_x:  -5.9760759838 v_y:  45.5998801714 v_z:  5.52930974379 sigma_v:  0.440128255757
# New N value:  217
# ID of excluded star:  [21280]
# Optimization terminated successfully.
#          Current function value: 2791.243200
#          Iterations: 22
#          Function evaluations: 27
#          Gradient evaluations: 466
#          Hessian evaluations: 0
# Min CL value:  4.46185830799e-05
# Likelihood:  2791.24320009
# v_x:  -5.97501362933 v_y:  45.6111947952 v_z:  5.53959555134 sigma_v:  0.429513631807
# New N value:  216
# ID of excluded star:  [3413223223234482176]
# Optimization terminated successfully.
#          Current function value: 2762.997173
#          Iterations: 23
#          Function evaluations: 28
#          Gradient evaluations: 566
#          Hessian evaluations: 0
# Min CL value:  2.08500091528e-05
# Likelihood:  2762.9971727
# v_x:  -5.98708158223 v_y:  45.6043414988 v_z:  5.54303135207 sigma_v:  0.411804173365
# New N value:  215
# ID of excluded star:  [3306303998130681856]
# Optimization terminated successfully.
#          Current function value: 2727.785916
#          Iterations: 25
#          Function evaluations: 30
#          Gradient evaluations: 546
#          Hessian evaluations: 0
# Min CL value:  3.15339478146e-05
# Likelihood:  2727.78591609
# v_x:  -5.98982351679 v_y:  45.6052025292 v_z:  5.55174662673 sigma_v:  0.394912444934
# New N value:  214
# ID of excluded star:  [3399771248225859072]
# Optimization terminated successfully.
#          Current function value: 2706.357370
#          Iterations: 14
#          Function evaluations: 19
#          Gradient evaluations: 210
#          Hessian evaluations: 0
# Min CL value:  4.51051514102e-05
# Likelihood:  2706.35736969
# v_x:  -5.99367441849 v_y:  45.613491017 v_z:  5.54582037282 sigma_v:  0.388673932309
# New N value:  213
# ID of excluded star:  [13117]
# Optimization terminated successfully.
#          Current function value: 2659.312671
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 400
#          Hessian evaluations: 0
# Min CL value:  4.98604564155e-05
# Likelihood:  2659.31267129
# v_x:  -5.99327219421 v_y:  45.6016620034 v_z:  5.54124114916 sigma_v:  0.388360485901
# New N value:  212
# ID of excluded star:  [144130512519598848]
# Optimization terminated successfully.
#          Current function value: 2626.953563
#          Iterations: 20
#          Function evaluations: 26
#          Gradient evaluations: 401
#          Hessian evaluations: 0
# Min CL value:  5.23772649704e-05
# Likelihood:  2626.95356289
# v_x:  -5.98368359637 v_y:  45.5977117215 v_z:  5.54379283383 sigma_v:  0.385347830696
# New N value:  211
# ID of excluded star:  [20086]
# Optimization terminated successfully.
#          Current function value: 2591.474835
#          Iterations: 19
#          Function evaluations: 22
#          Gradient evaluations: 322
#          Hessian evaluations: 0
# Min CL value:  0.000100515116457
# Likelihood:  2591.47483477
# v_x:  -5.98662709879 v_y:  45.5897227546 v_z:  5.54811938669 sigma_v:  0.377693741575
# New N value:  210
# ID of excluded star:  [3444787247130393600]
# Optimization terminated successfully.
#          Current function value: 2568.445836
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 428
#          Hessian evaluations: 0
# Min CL value:  0.000168226752238
# Likelihood:  2568.4458356
# v_x:  -5.99875623071 v_y:  45.5805775543 v_z:  5.54435686224 sigma_v:  0.374553269311
# New N value:  209
# ID of excluded star:  [20205]
# Warning: CG iterations didn't converge.  The Hessian is not positive definite.
#          Current function value: 3252.853510
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 8537
#          Hessian evaluations: 0
# Min CL value:  1.76730775938e-29
# Likelihood:  3252.8535097
# v_x:  -6.27233960196 v_y:  45.2557977259 v_z:  5.34219713505 sigma_v:  0.896606509876
# New N value:  208
# ID of excluded star:  [21092]
# Warning: CG iterations didn't converge.  The Hessian is not positive definite.
#          Current function value: 3103.625857
#          Iterations: 4
#          Function evaluations: 5
#          Gradient evaluations: 8497
#          Hessian evaluations: 0
# Min CL value:  1.44743918716e-09
# Likelihood:  3103.62585731
# v_x:  -6.26960734593 v_y:  45.2541989739 v_z:  5.34251157089 sigma_v:  0.886235555411
# New N value:  207
# ID of excluded star:  [20873]
# Optimization terminated successfully.
#          Current function value: 2491.343721
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 275
#          Hessian evaluations: 0
# Min CL value:  0.000356116081138
# Likelihood:  2491.34372121
# v_x:  -5.98396814314 v_y:  45.5648302265 v_z:  5.54654323712 sigma_v:  0.367616202246
# New N value:  206
# ID of excluded star:  [3406216379227985920]
# Optimization terminated successfully.
#          Current function value: 2461.315514
#          Iterations: 17
#          Function evaluations: 19
#          Gradient evaluations: 223
#          Hessian evaluations: 0
# Min CL value:  0.000243683174009
# Likelihood:  2461.31551441
# v_x:  -5.99629813252 v_y:  45.559632247 v_z:  5.54778482304 sigma_v:  0.357017118148
# New N value:  205
# ID of excluded star:  [3310876798270577664]
# Optimization terminated successfully.
#          Current function value: 2433.892421
#          Iterations: 19
#          Function evaluations: 21
#          Gradient evaluations: 273
#          Hessian evaluations: 0
# Min CL value:  0.000210144736845
# Likelihood:  2433.89242126
# v_x:  -5.99838632414 v_y:  45.5539553842 v_z:  5.53660993192 sigma_v:  0.343524496643
# New N value:  204
# ID of excluded star:  [173447237727870080]
# Optimization terminated successfully.
#          Current function value: 2411.795789
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 288
#          Hessian evaluations: 0
# Min CL value:  0.000169245705935
# Likelihood:  2411.79578913
# v_x:  -5.9865324103 v_y:  45.5707337398 v_z:  5.5368364186 sigma_v:  0.334542449265
# New N value:  203
# ID of excluded star:  [20542]
# Optimization terminated successfully.
#          Current function value: 2383.616012
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 270
#          Hessian evaluations: 0
# Min CL value:  0.000127720393906
# Likelihood:  2383.61601227
# v_x:  -5.98191193832 v_y:  45.5639940786 v_z:  5.54374389578 sigma_v:  0.325722848632
# New N value:  202
# ID of excluded star:  [20215]
# Optimization terminated successfully.
#          Current function value: 2353.177583
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 284
#          Hessian evaluations: 0
# Min CL value:  0.000240066085158
# Likelihood:  2353.17758337
# v_x:  -5.98251091354 v_y:  45.5576616402 v_z:  5.5489975125 sigma_v:  0.31794233881
# New N value:  201
# ID of excluded star:  [3402090461845409792]
# Optimization terminated successfully.
#          Current function value: 2331.846239
#          Iterations: 19
#          Function evaluations: 22
#          Gradient evaluations: 342
#          Hessian evaluations: 0
# Min CL value:  0.000285060014879
# Likelihood:  2331.84623897
# v_x:  -5.98150134484 v_y:  45.5631149001 v_z:  5.54616359017 sigma_v:  0.315366976238
# New N value:  200
# ID of excluded star:  [3302220274506270208]
# Optimization terminated successfully.
#          Current function value: 2303.662850
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 296
#          Hessian evaluations: 0
# Min CL value:  0.000322426798117
# Likelihood:  2303.66284961
# v_x:  -5.98959678765 v_y:  45.557606784 v_z:  5.54210843475 sigma_v:  0.31575686428
# New N value:  199
# ID of excluded star:  [22607]
# Optimization terminated successfully.
#          Current function value: 2274.397919
#          Iterations: 19
#          Function evaluations: 22
#          Gradient evaluations: 284
#          Hessian evaluations: 0
# Min CL value:  0.000256392738066
# Likelihood:  2274.39791881
# v_x:  -5.98587888542 v_y:  45.5621192094 v_z:  5.53633097274 sigma_v:  0.305946536462
# New N value:  198
# ID of excluded star:  [3310500078099136512]
# Optimization terminated successfully.
#          Current function value: 2246.635172
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 336
#          Hessian evaluations: 0
# Min CL value:  0.000136824701551
# Likelihood:  2246.63517226
# v_x:  -5.98607849936 v_y:  45.5607265854 v_z:  5.54405105499 sigma_v:  0.293821576459
# New N value:  197
# ID of excluded star:  [21137]
# Optimization terminated successfully.
#          Current function value: 2215.857922
#          Iterations: 22
#          Function evaluations: 25
#          Gradient evaluations: 382
#          Hessian evaluations: 0
# Min CL value:  0.000239734674353
# Likelihood:  2215.85792162
# v_x:  -5.98351321001 v_y:  45.563780515 v_z:  5.55313082025 sigma_v:  0.282389829196
# New N value:  196
# ID of excluded star:  [22157]
# Optimization terminated successfully.
#          Current function value: 2190.929297
#          Iterations: 20
#          Function evaluations: 23
#          Gradient evaluations: 314
#          Hessian evaluations: 0
# Min CL value:  0.000238839440646
# Likelihood:  2190.92929657
# v_x:  -5.9773118532 v_y:  45.5538119542 v_z:  5.55215883941 sigma_v:  0.280279065369
# New N value:  195
# ID of excluded star:  [64266763882171648]
# Optimization terminated successfully.
#          Current function value: 2164.695296
#          Iterations: 21
#          Function evaluations: 26
#          Gradient evaluations: 402
#          Hessian evaluations: 0
# Min CL value:  0.000261312741113
# Likelihood:  2164.69529571
# v_x:  -5.97326965296 v_y:  45.5663443171 v_z:  5.54788112857 sigma_v:  0.268751272622
# New N value:  194
# ID of excluded star:  [21670]
# Optimization terminated successfully.
#          Current function value: 2138.896915
#          Iterations: 21
#          Function evaluations: 24
#          Gradient evaluations: 378
#          Hessian evaluations: 0
# Min CL value:  0.000455257604467
# Likelihood:  2138.89691481
# v_x:  -5.9598552406 v_y:  45.5869847775 v_z:  5.55831846692 sigma_v:  0.267447866197
# New N value:  193
# ID of excluded star:  [3216618964956221440]
# Optimization terminated successfully.
#          Current function value: 2119.941288
#          Iterations: 20
#          Function evaluations: 21
#          Gradient evaluations: 324
#          Hessian evaluations: 0
# Min CL value:  0.000776321482468
# Likelihood:  2119.94128806
# v_x:  -5.97050126053 v_y:  45.5795349413 v_z:  5.55388231941 sigma_v:  0.266145246614
# New N value:  192
# ID of excluded star:  [22350]
# Optimization terminated successfully.
#          Current function value: 2089.369096
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 339
#          Hessian evaluations: 0
# Min CL value:  0.000797918548572
# Likelihood:  2089.36909649
# v_x:  -5.96853150577 v_y:  45.5807109145 v_z:  5.55274288585 sigma_v:  0.265517978964
# New N value:  191
# ID of excluded star:  [22044]
# Optimization terminated successfully.
#          Current function value: 2066.014753
#          Iterations: 21
#          Function evaluations: 23
#          Gradient evaluations: 327
#          Hessian evaluations: 0
# Min CL value:  0.000701865231796
# Likelihood:  2066.01475332
# v_x:  -5.95342821017 v_y:  45.590955862 v_z:  5.56388453699 sigma_v:  0.26020827067
# New N value:  190
# ID of excluded star:  [21273]
# Optimization terminated successfully.
#          Current function value: 2040.616243
#          Iterations: 19
#          Function evaluations: 24
#          Gradient evaluations: 286
#          Hessian evaluations: 0
# Min CL value:  0.000894639483811
# Likelihood:  2040.61624287
# v_x:  -5.94539555766 v_y:  45.5977393784 v_z:  5.57228843026 sigma_v:  0.256450533425
# New N value:  189
# ID of excluded star:  [3388382060107609088]
# Optimization terminated successfully.
#          Current function value: 2019.549362
#          Iterations: 21
#          Function evaluations: 28
#          Gradient evaluations: 366
#          Hessian evaluations: 0
# Min CL value:  0.00140410977935
# Likelihood:  2019.54936203
# v_x:  -5.94035200312 v_y:  45.5995067144 v_z:  5.5777117424 sigma_v:  0.254512388182
# New N value:  188
# ID of excluded star:  [21029]
# Optimization terminated successfully.
#          Current function value: 1996.814185
#          Iterations: 18
#          Function evaluations: 26
#          Gradient evaluations: 369
#          Hessian evaluations: 0
# Min CL value:  0.00170774228311
# Likelihood:  1996.81418535
# v_x:  -5.95078942908 v_y:  45.6042673084 v_z:  5.57314553941 sigma_v:  0.251760932827
# New N value:  187
# ID of excluded star:  [20916]
# Optimization terminated successfully.
#          Current function value: 1972.067521
#          Iterations: 20
#          Function evaluations: 26
#          Gradient evaluations: 2603
#          Hessian evaluations: 0
# Min CL value:  0.0022062975444
# Likelihood:  1972.0675205
# v_x:  -5.95624908368 v_y:  45.6016152888 v_z:  5.57181113414 sigma_v:  0.251901638147
# New N value:  186
# ID of excluded star:  [59364144612120064]
# Optimization terminated successfully.
#          Current function value: 1957.549253
#          Iterations: 20
#          Function evaluations: 26
#          Gradient evaluations: 349
#          Hessian evaluations: 0
# Min CL value:  0.00236823681436
# Likelihood:  1957.54925264
# v_x:  -5.95531330917 v_y:  45.5934584489 v_z:  5.57228341509 sigma_v:  0.251876212535
# New N value:  185
# ID of excluded star:  [67270457850822912]
# Optimization terminated successfully.
#          Current function value: 1938.154870
#          Iterations: 21
#          Function evaluations: 26
#          Gradient evaluations: 338
#          Hessian evaluations: 0
# Min CL value:  0.00299886308237
# Likelihood:  1938.15486979
# v_x:  -5.95978412661 v_y:  45.5906338597 v_z:  5.573346764 sigma_v:  0.250357192308

# %%
print('sigma_v_x:', np.round(err_param[-4], 2))
print('sigma_v_y:', np.round(err_param[-3], 2))
print('sigma_v_z:', np.round(err_param[-2], 2))
print('sigma_sigmav', np.round(err_param[-1], 2))
# Out:
# sigma_v_x: 0.03
# sigma_v_y: 0.06
# sigma_v_z: 0.07
# sigma_sigmav 0.01
